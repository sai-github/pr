# %%
import numpy as np
import glob

import cv2

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

import tensorflow as tf

from keras.models import Sequential
from keras.layers.core import Dense, Activation, Flatten, Dropout

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
X = []
Y = []

for i in glob.glob('data\\a\\*'): #windows \\
    image = cv2.imread(i)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    resized = cv2.resize(gray_image, (30,30), interpolation = cv2.INTER_AREA)
    X.append(resized.reshape(-1,))
    Y.append(0)
    
for i in glob.glob('data\\dA\\*'):
    image = cv2.imread(i)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    resized = cv2.resize(gray_image, (30,30), interpolation = cv2.INTER_AREA)
    X.append(resized.reshape(-1,))
    Y.append(1)
    
for i in glob.glob('data\\tA\\*'):
    image = cv2.imread(i)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    resized = cv2.resize(gray_image, (30,30), interpolation = cv2.INTER_AREA)
    X.append(resized.reshape(-1,))
    Y.append(2)
    
X = np.array(X)
X = (X)/255
Y = np.array(Y)
label_binarizer = LabelBinarizer()
Y = label_binarizer.fit_transform(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
from keras.preprocessing.image import ImageDataGenerator

from keras import backend as K
K.set_image_dim_ordering('th')

# %%
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False)

X_train = X_train.reshape(-1,1,30,30).astype('float32')
datagen.fit(X_train.reshape(-1,1,30,30).astype('float32'))

# %%
x_aug = []
y_aug = []

i=0
for X_batch, y_batch in datagen.flow(X_train, Y_train, batch_size=1000):
    x_aug.append(X_batch)
    y_aug.append(y_batch)
    i+=1
    if i>40:
        break
        
x_aug = np.array(x_aug).reshape(-1,30,30)
y_aug = np.array(y_aug).reshape(-1,3)

# %%
x_aug.shape
# Out:
# (8528, 30, 30)

# %%
fig = plt.figure(figsize = (15,25))
for i in range(50):
    plt.subplot(10,5,i+1)
    index = np.random.randint(0,8000)
    plt.imshow(x_aug[index])
    plt.title(str(y_aug[index]))
    plt.axis('off')
plt.show()

# %%
x_aug = x_aug.reshape(-1,900)

# %%
class_count = [0,0,0]
for i in Y_test:
    if (i==[1,0,0]).all():
        class_count[0]+=1
    elif (i==[0,1,0]).all():
        class_count[1]+=1
    else:
        class_count[2]+=1
        
class_count
# Out:
# [32, 25, 33]

# %%
from sklearn.utils import shuffle
x_aug, y_aug = shuffle(x_aug, y_aug)

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(900,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax'))
model.add(Activation('softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 512)               461312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 1539
# _________________________________________________________________
# activation_2 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 725,507
# Trainable params: 725,507
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', metrics=['accuracy'], loss='categorical_crossentropy')
history = model.fit(x_aug, y_aug, epochs=20, batch_size=1024)
# Out:
# Epoch 1/20
# 8528/8528 [==============================] - 6s - loss: 0.8118 - acc: 0.7556
# Epoch 2/20
# 8528/8528 [==============================] - 0s - loss: 0.5947 - acc: 0.9600
# Epoch 3/20
# 8528/8528 [==============================] - 0s - loss: 0.5732 - acc: 0.9797
# Epoch 4/20
# 8528/8528 [==============================] - 0s - loss: 0.5667 - acc: 0.9851
# Epoch 5/20
# 8528/8528 [==============================] - 0s - loss: 0.5632 - acc: 0.9883
# Epoch 6/20
# 8528/8528 [==============================] - 0s - loss: 0.5608 - acc: 0.9911
# Epoch 7/20
# 8528/8528 [==============================] - 0s - loss: 0.5593 - acc: 0.9927
# Epoch 8/20
# 8528/8528 [==============================] - 0s - loss: 0.5583 - acc: 0.9933
# Epoch 9/20
# 8528/8528 [==============================] - 0s - loss: 0.5571 - acc: 0.9946
# Epoch 10/20
# 8528/8528 [==============================] - 0s - loss: 0.5566 - acc: 0.9952
# Epoch 11/20
# 8528/8528 [==============================] - 0s - loss: 0.5559 - acc: 0.9955
# Epoch 12/20
# 8528/8528 [==============================] - 0s - loss: 0.5555 - acc: 0.9961
# Epoch 13/20
# 8528/8528 [==============================] - 0s - loss: 0.5553 - acc: 0.9962
# Epoch 14/20
# 8528/8528 [==============================] - 0s - loss: 0.5549 - acc: 0.9968
# Epoch 15/20
# 8528/8528 [==============================] - 0s - loss: 0.5549 - acc: 0.9970
# Epoch 16/20
# 8528/8528 [==============================] - 0s - loss: 0.5545 - acc: 0.9972
# Epoch 17/20
# 8528/8528 [==============================] - 0s - loss: 0.5543 - acc: 0.9973
# Epoch 18/20
# 8528/8528 [==============================] - 0s - loss: 0.5542 - acc: 0.9974
# Epoch 19/20
# 8528/8528 [==============================] - 0s - loss: 0.5541 - acc: 0.9974
# Epoch 20/20
# 8528/8528 [==============================] - 0s - loss: 0.5541 - acc: 0.9973

# %%
model.evaluate(X_test, Y_test)
# Out:
# 32/90 [=========>....................] - ETA: 0s
# [1.1954876846737332, 0.3555555582046509]

# %%
A = np.array([[1, 2],[3,4],[5,6]])

B = np.pad(A, ((0,4-A.shape[0]),(0,0)), mode='constant')

# %%
B.reshape(-1,1)
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6],
#        [0],
#        [0]])

# %%
def unbin(y_aug):
    y_class = []
    for i in y_aug:
        if (i==[1,0,0]).all():
            y_class.append(1)
        elif (i==[0,1,0]).all():
            y_class.append(2)
        else:
            y_class.append(3)
    return np.array(y_class)

y_class = unbin(y_aug)

# %% [markdown]
# #### Using SVM (extracted features)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='poly', class_weight='balanced', C=2)
clf.fit(x_aug, y_class)
# Out:
# SVC(C=2, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
X_ex = np.load("extracted_data/X.npy")
Y_ex = np.load("extracted_data/Y.npy")


X_train_ex, X_test_ex, Y_train_ex, Y_test_ex = train_test_split(X_ex, Y_ex, test_size=0.3)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='linear', class_weight='balanced', C=1)
clf.fit(X_train_ex, Y_train_ex) 

clf.score(X_test_ex, Y_test_ex)
# Out:
# 0.98888888888888893

# %% [markdown]
# #### ANN (extracted features)

# %%
Y_ex_hot = label_binarizer.fit_transform(Y_ex)
X_train_ex, X_test_ex, Y_train_ex_hot, Y_test_ex_hot = train_test_split(X_ex, Y_ex_hot, test_size=0.3)

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(1274,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax'))
model.add(Activation('softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 512)               652800
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 1539
# _________________________________________________________________
# activation_6 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 916,995
# Trainable params: 916,995
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'sgd', metrics=['accuracy'], loss='categorical_crossentropy')
history = model.fit(X_train_ex, Y_train_ex_hot, epochs=10, batch_size=1024)
# Out:
# Epoch 1/10
# 208/208 [==============================] - 0s - loss: 0.5707 - acc: 0.9760
# Epoch 2/10
# 208/208 [==============================] - 0s - loss: 0.5629 - acc: 0.9856
# Epoch 3/10
# 208/208 [==============================] - 0s - loss: 0.5679 - acc: 0.9808
# Epoch 4/10
# 208/208 [==============================] - 0s - loss: 0.5662 - acc: 0.9856
# Epoch 5/10
# 208/208 [==============================] - 0s - loss: 0.5657 - acc: 0.9856
# Epoch 6/10
# 208/208 [==============================] - 0s - loss: 0.5676 - acc: 0.9856
# Epoch 7/10
# 208/208 [==============================] - 0s - loss: 0.5662 - acc: 0.9856
# Epoch 8/10
# 208/208 [==============================] - 0s - loss: 0.5661 - acc: 0.9904
# Epoch 9/10
# 208/208 [==============================] - 0s - loss: 0.5631 - acc: 0.9904
# Epoch 10/10
# 208/208 [==============================] - 0s - loss: 0.5639 - acc: 0.9856

# %%
model.evaluate(X_test_ex, Y_test_ex_hot)
# Out:
# 32/90 [=========>....................] - ETA: 0s
# [0.58140873511632285, 0.96666667593850031]
